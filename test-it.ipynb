# %%
from datetime import datetime, timedelta
current_date = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

# %%
current_date
# Out:
# '2023-11-16'

# %%
# !pip install boto3
# !pip install logging
import logging 
import boto3

# %%
aws_access_key_id='AKIAQIJYZFTTQGNPLLKQ'
aws_secret_access_key= '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'
# bucket = s3.Bucket('transactionlogging')
s3_bucket_name = 'transactionlogging'
s3_prefix = 'transactions-'
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
current_date = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')


s3_client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)
logger.info("Checking for the file in bucket '%s'", s3_bucket_name)
response = s3_client.list_objects(Bucket=s3_bucket_name, Prefix=s3_prefix)
file_key = None
for obj in response.get('Contents', []):
    if current_date in obj['Key']:
        file_key = obj['Key']
        logger.info('Found file: %s', file_key)
# Out:
# INFO:__main__:Checking for the file in bucket 'transactionlogging'
# INFO:__main__:Found file: transactions-2023-11-16.csv

# %%
import boto3
from botocore.exceptions import NoCredentialsError, ClientError

aws_access_key_id='AKIAQIJYZFTTQGNPLLKQ'
aws_secret_access_key= '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'
# bucket = s3.Bucket('transactionlogging')
s3_bucket_name = 'transactionlogging'
s3_prefix = 'transactions-'
s3 = boto3.client('s3',aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)
bucket_name = 'transactionlogging'
file_key = 'transactions-2023-11-16.csv'

try:
    s3.head_object(Bucket=bucket_name, Key=file_key)
    print(f"The file {file_key} exists in bucket {bucket_name}.")
except ClientError as e:
    error_code = e.response['Error']['Code']
    if error_code == '404':
        print(f"The file {file_key} does not exist in bucket {bucket_name}.")
    else:
        print(f"An error occurred: {e}")
except NoCredentialsError:
    print("Credentials not available")
# Out:
# The file transactions-2023-11-16.csv exists in bucket transactionlogging.

# %%
import csv

obj = s3.get_object(Bucket=bucket_name, Key=file_key)
data = obj['Body'].read().decode('utf-8').splitlines(True)
reader = csv.DictReader(data)             
batch = []
for row in reader:
    print(row)
# Out:
# {'date': '2023-06-08 21:12:12', 'externalId': '204093b5403dc88771f356bd05c3bf28c147619ab2bbccc3ad578bef8766076c', 'agentPhoneNumber': '220775796633', 'transactionType': 'deposit', 'amount': '30000.0', 'balance': '53541.0', 'receiverPhoneNumber': '220785529271', 'commission': '225.0'}
# {'date': '2023-06-08 23:03:58', 'externalId': '0d7a72db578beaa6c0d828a22c95b3c6ba75d790fa79b80326a556aefa1263dd', 'agentPhoneNumber': '220775796633', 'transactionType': 'deposit', 'amount': '2000.0', 'balance': '51541.0', 'receiverPhoneNumber': '220774328626', 'commission': '80.0'}
# {'date': '2023-06-08 11:59:43', 'externalId': '2da421d359d2f27999e234ffcd4b91c9dfb44fc946466009f6107fcc8e07bd30', 'agentPhoneNumber': '220789779204', 'transactionType': 'deposit', 'amount': '25100.0', 'balance': '568719.0', 'receiverPhoneNumber': '220788493800', 'commission': '225.0'}
# ...

# %%
bucket = s3.Bucket(bucket_name)

obj = bucket.Object(key=file_name)

response = obj.get()
lines = response['Body'].read().decode('utf-8').splitlines(True)

reader = csv.DictReader(lines)
for row in reader:
    print(row[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/margaretchege/Desktop/project_siri/test-it.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/margaretchege/Desktop/project_siri/test-it.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> bucket = client.Bucket(bucket_name)
#       <a href='vscode-notebook-cell:/Users/margaretchege/Desktop/project_siri/test-it.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> obj = bucket.Object(key=file_name)
#       <a href='vscode-notebook-cell:/Users/margaretchege/Desktop/project_siri/test-it.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> response = obj.get()
#
# NameError: name 'client' is not defined
